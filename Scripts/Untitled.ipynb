# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
associated = np.loadtxt('list_associated.txt', dtype='str')

# %%
intervening = np.loadtxt('list_intervening.txt', dtype='str')

# %%
len(intervening)
# Out:
# 29

# %%
for i in intervening:
    
    tmp = np.loadtxt(i)
    name = (i.split('/')[-1]).split('.DAT')[0]
    plt.plot(tmp[:,0], tmp[:,1])
    plt.title(name)
    plt.show()
