# %%
import numpy as np
import matplotlib.pyplot as plt
from glob import glob
import json

# %%
data = np.sort( glob('spectra/*') )
plt.figure(figsize=(15, 100))
plt.subplots_adjust(hspace=0.5)
plt.suptitle("Associated Spectra (Curran)", fontsize=18)

for n, i in enumerate(data):
    ax = plt.subplot(24, 2, n + 1)
    
    name = i.split('/')[1].split('_')[0]
    #print(name)
    
    loaded = np.loadtxt(i)
    
    ax.plot(loaded[:,0], loaded[:,1])

    ax.set_title(name)
    ax.set_xlabel("Velocity")
    ax.set_ylabel('Optical depth')
    fig = ax.get_figure()
    fig.tight_layout()
    fig.subplots_adjust(top=0.95)

# %%
data_r = np.sort( glob('spectra_reversed/*') )
plt.figure(figsize=(15, 100))
plt.subplots_adjust(hspace=0.5)
plt.suptitle("Associated Spectra (Curran)", fontsize=18)

for n, i in enumerate(data_r):
    ax = plt.subplot(24, 2, n + 1)
    
    name = i.split('/')[1].split('_')[0]
    
    loaded = np.loadtxt(i)
    
    ax.plot(loaded[:,0], loaded[:,1])

    ax.set_title(name)
    ax.set_xlabel("Velocity")
    ax.set_ylabel('Optical depth')
    fig = ax.get_figure()
    fig.tight_layout()
    fig.subplots_adjust(top=0.95)
